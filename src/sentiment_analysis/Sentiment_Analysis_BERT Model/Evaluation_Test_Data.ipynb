# %%
# Import pandas library
import pandas as pd

# Here Prediction__bert_output.csv is the Test Data here
df = pd.read_csv('/content/drive/MyDrive/CS5344_Project/Dataset/Prediction__bert_output.csv')

# %%
df.head(6)
# Out:
#    2  2.1
# 0  2    2
# 1  0    0
# 2  0    1
# 3  2    2
# 4  2    1
# 5  0    0

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 'label' is indicated by 2 and 'prediction' is indicated by 2.1 are  columns
y_true = df['2']
y_pred = df['2.1']


# Compute and print metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')  # Specify the average parameter
recall = recall_score(y_true, y_pred, average='weighted')  # Specify the average parameter
f1 = f1_score(y_true, y_pred, average='weighted')  # Specify the average parameter
conf_matrix = confusion_matrix(y_true, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1-Score: {f1}')
print(f'Confusion Matrix:\n{conf_matrix}')

# Plot Confusion Matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.8269371086456538
# Precision: 0.9135732305658737
# Recall: 0.8269371086456538
# F1-Score: 0.8577872926099301
# Confusion Matrix:
# [[ 41102   8934   1010]
#  [  3598  19135   2896]
#  [  3973  41969 237830]]
